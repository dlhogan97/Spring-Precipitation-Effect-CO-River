# %%
import pandas as pd
import rioxarray as rxr
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np

# %%
# get all gages basin characteristics
basin_df = pd.read_csv('../basin_characteristics/gagesII/conterm_basinid.txt', encoding='utf-8')
# filter to HUC02 == 14
basin_df = basin_df[basin_df['HUC02'] == '14']
huc14_stations = basin_df['STAID'].tolist()

# %%
# now open the dam data
dam_df = pd.read_csv('../basin_characteristics/gagesII/conterm_hydromod_dams.txt', encoding='utf-8')
dam_df = dam_df[dam_df['STAID'].isin(huc14_stations)]
# drop all NDAMS_2009 > 0
dam_df = dam_df[dam_df['pre1980_NDAMS'] > 1]
# get damn free ids 
dam_stations = dam_df['STAID'].tolist()

# %%
# drop values from huc14_stations if in dam_stations
huc14_dam_free = [x for x in huc14_stations if x not in dam_stations]

# %%
# get flow record data
flowrec_df = pd.read_csv('../basin_characteristics/gagesII/conterm_flowrec.txt', encoding='utf-8')
flowrec_df = flowrec_df[flowrec_df['STAID'].isin(huc14_dam_free)]
# create a list filled with strings from wy1964 to wy2009
years = list(map(str, list(range(1964, 2010))))
# add wy to each string
years = list(map(lambda x: 'wy' + x, years))
# for each row, get the sum of the years columns
flowrec_df['sum'] = flowrec_df[years].sum(axis=1)
# drop if sum is less than 43
flowrec_df = flowrec_df[flowrec_df['sum'] >= 43]
# drop years not active09
flowrec_df = flowrec_df[flowrec_df['ACTIVE09'] == 'yes']
# get the station ids
flowrec_stations = flowrec_df['STAID'].tolist()

# %%
final_basins = basin_df[basin_df['STAID'].isin(flowrec_stations)]
# drop basins with areas  < 10 km^2
final_basins = final_basins[final_basins['DRAIN_SQKM'] > 50]
final_basin_gages = final_basins['STAID'].tolist()
final_basin_gages = ['0'+str(v) for v in final_basin_gages]
final_basins.loc[:,'STAID'] = final_basin_gages

# %%
final_basins
# Out:
#          STAID                                            STANAME  DRAIN_SQKM  \
# 6591  09010500   COLORADO R BELOW BAKER GULCH, NR GRAND LAKE, CO.       163.0
# 6598  09024000                   FRASER RIVER AT WINTER PARK, CO.        71.6
# 6599  09025000                  VASQUEZ CREEK AT WINTER PARK, CO.        73.8
# 6602  09026500                   ST. LOUIS CREEK NEAR FRASER, CO.        85.3
# 6603  09032000                       RANCH CREEK NEAR FRASER, CO.        51.8
# 6610  09035700    WILLIAMS FORK ABOVE DARLING CREEK, NR LEAL, CO.        91.5
# 6612  09035900         SOUTH FORK OF WILLIAMS FORK NEAR LEAL, CO.        72.8
# 6613  09036000                       WILLIAMS FORK NEAR LEAL, CO.       231.9
# 6640  09059500                 PINEY RIVER NEAR STATE BRIDGE, CO.       241.8
# 6647  09064500                HOMESTAKE CREEK NEAR RED CLIFF, CO.       151.3
# 6678  09081600   CRYSTAL RIVER AB AVALANCHE C, NEAR REDSTONE, CO.       432.9
# 6693  09109000      TAYLOR RIVER BELOW TAYLOR PARK RESERVOIR, CO.       659.8
# 6696  09112500                           EAST RIVER AT ALMONT CO.       749.0
# 6702  09124500                         LAKE FORK AT GATEVIEW, CO.       879.2
# 6731  09165000                      DOLORES RIVER BELOW RICO, CO.       273.5
# 6732  09166500                      DOLORES RIVER AT DOLORES, CO.      1306.9
# 6752  09188500      GREEN RIVER AT WARREN BRIDGE, NEAR DANIEL, WY      1210.2
# 6755  09196500                  PINE CREEK ABOVE FREMONT LAKE, WY       194.9
# 6767  09210500  FONTENELLE C NR HERSCHLER RANCH, NR FONTENELLE...       398.3
# 6781  09223000      HAMS FORK BELOW POLE CREEK, NEAR FRONTIER, WY       333.2
# 6812  09253000                LITTLE SNAKE RIVER NEAR SLATER, CO.       649.6
# 6813  09255000                       SLATER FORK NEAR SLATER, CO.       387.9
# 6831  09277500                    DUCHESNE RIVER NEAR TABIONA, UT       923.8
# 6835  09279000                  ROCK CREEK NEAR MOUNTAIN HOME, UT       379.2
# 6844  09288000                   CURRANT CREEK NEAR FRUITLAND, UT       363.6
# 6848  09289500  LAKE FORK RIVER AB MOON LAKE, NR MOUNTAIN HOME...       201.5
# 6917  09352900                 VALLECITO CREEK NEAR BAYFIELD, CO.       188.2
# 6938  09365500                    LA PLATA RIVER AT HESPERUS, CO.        84.1
#
#      HUC02   LAT_GAGE    LNG_GAGE STATE  BOUND_SOURCE HCDN-2009 HBN36  \
# 6591    14  40.325818 -105.856679    CO             4       NaN   NaN
# 6598    14  39.899987 -105.776674    CO             1       NaN   NaN
# 6599    14  39.920265 -105.785286    CO             1       NaN   NaN
# 6602    14  39.909987 -105.878345    CO             1       NaN   NaN
# 6603    14  39.949987 -105.765563    CO             1       NaN   NaN
# 6610    14  39.797208 -106.026129    CO             1       NaN   NaN
# 6612    14  39.795820 -106.030573    CO             4       yes   NaN
# 6613    14  39.833875 -106.056408    CO             1       NaN   NaN
# 6640    14  39.799987 -106.583923    CO             1       NaN   NaN
# 6647    14  39.473320 -106.367806    CO             1       NaN   NaN
# 6678    14  39.232207 -107.227273    CO             1       yes   NaN
# 6693    14  38.818327 -106.609198    CO             1       NaN   NaN
# 6696    14  38.664437 -106.848095    CO             1       NaN   NaN
# 6702    14  38.298883 -107.230056    CO             1       NaN   NaN
# 6731    14  37.638884 -108.060352    CO             1       NaN   NaN
# 6732    14  37.472493 -108.497591    CO             1       NaN   NaN
# 6752    14  43.018829 -110.118220    WY             1       NaN   NaN
# 6755    14  43.030502 -109.770153    WY             3       NaN   yes
# 6767    14  42.096053 -110.416556    WY             1       yes   NaN
# 6781    14  42.110494 -110.709621    WY             1       yes   NaN
# 6812    14  40.999410 -107.143388    CO             1       NaN   NaN
# 6813    14  40.982466 -107.382839    CO             3       NaN   NaN
# 6831    14  40.300230 -110.602381    UT             1       NaN   NaN
# 6835    14  40.493280 -110.578217    UT             1       NaN   NaN
# 6844    14  40.200231 -110.907662    UT             1       NaN   NaN
# 6848    14  40.606613 -110.527107    UT             1       NaN   NaN
# 6917    14  37.477501 -107.543669    CO             3       yes   yes
# 6938    14  37.289722 -108.040628    CO             1       NaN   NaN
#
#      OLD_HCDN NSIP_SENTINEL  FIPS_SITE COUNTYNAME_SITE NAWQA_SUID
# 6591      NaN           NaN       8049           Grand       ucol
# 6598      NaN           NaN       8049           Grand        NaN
# 6599      NaN           NaN       8049           Grand        NaN
# 6602      NaN           NaN       8049           Grand        NaN
# 6603      NaN           NaN       8049           Grand        NaN
# 6610      NaN           NaN       8049           Grand        NaN
# 6612      NaN           NaN       8049           Grand       ucol
# 6613      NaN           NaN       8049           Grand        NaN
# 6640      NaN           NaN       8037           Eagle        NaN
# 6647      NaN           NaN       8037           Eagle        NaN
# 6678      yes           yes       8097          Pitkin        NaN
# 6693      NaN           NaN       8051        Gunnison        NaN
# 6696      yes           NaN       8051        Gunnison        NaN
# 6702      yes           yes       8051        Gunnison        NaN
# 6731      yes           yes       8033         Dolores        NaN
# 6732      NaN           NaN       8083       Montezuma        NaN
# 6752      yes           NaN      56035        Sublette        NaN
# 6755      yes           NaN      56035        Sublette        NaN
# 6767      yes           yes      56023         Lincoln        NaN
# 6781      yes           NaN      56023         Lincoln        NaN
# 6812      NaN           NaN       8107           Routt        NaN
# 6813      NaN           NaN       8081          Moffat        NaN
# 6831      NaN           NaN      49013        Duchesne        NaN
# 6835      NaN           NaN      49013        Duchesne        NaN
# 6844      NaN           NaN      49051         Wasatch        NaN
# 6848      NaN           NaN      49013        Duchesne        NaN
# 6917      yes           yes       8067        La Plata        NaN
# 6938      NaN           NaN       8067        La Plata        NaN

# %%
# get basin boundaries
basin_boudary_gdf = gpd.read_file('../basin_characteristics/gagesII/nonref_shapefile/bas_nonref_WestMnts.shp')
basin_boundary_ref_gdf = gpd.read_file('../basin_characteristics/gagesII/ref_shapefile/bas_ref_all.shp')

# %%
ucrb_selected_gdf_nonref = basin_boudary_gdf[basin_boudary_gdf['GAGE_ID'].isin(final_basin_gages)]
ucrb_selected_gdf_ref = basin_boundary_ref_gdf[basin_boundary_ref_gdf['GAGE_ID'].isin(final_basin_gages)]
# merge the two dataframes
ucrb_selected_gdf = pd.concat([ucrb_selected_gdf_nonref, ucrb_selected_gdf_ref])
# from final_basins, add these columns to the gdf: STANAME	DRAIN_SQKM	HUC02	LAT_GAGE	LNG_GAGE
ucrb_selected_gdf = ucrb_selected_gdf.merge(final_basins, left_on='GAGE_ID', right_on='STAID')

# %%
# transform crs to 32613
ucrb_selected_gdf_32613 = ucrb_selected_gdf.to_crs(epsg=32613)
# convert to 4326
ucrb_selected_gdf_4326 = ucrb_selected_gdf.to_crs(epsg=4326)

# %%
ucrb_boundary = gpd.read_file('../data/geodata/Upper_Colorado_River_Basin_Boundary.json')
#  transform crs to 32613
ucrb_boundary_32613 = ucrb_boundary.to_crs(epsg=32613)

# %%
fig, ax = plt.subplots()
ucrb_boundary_32613.plot(ax=ax)
ucrb_selected_gdf_32613.plot(ax=ax, color='red')
# Out:
# <Axes: >

# %%
# pull in the dem 
ucrb_dem = rxr.open_rasterio('../data/geodata/ucrb_dem_32613_150m.tif')

# %%
# iterate through each basin and get the mean elevation, max elevation, and min elevation
for idx, row in ucrb_selected_gdf_32613.iterrows():
    # get the basin boundary
    basin_boundary = row['geometry']
    # get the mean elevation
    tmp = ucrb_dem.rio.clip([basin_boundary], crs=32613)
    # fill negative values with nan
    tmp = tmp.where(tmp > 0, np.nan)
    mean_elevation = tmp.mean().values
    # get the max elevation
    max_elevation = tmp.max().values
    # get the min elevation
    min_elevation = tmp.min().values
    # add the values to the gdf
    ucrb_selected_gdf_32613.loc[idx, 'mean_elevation'] = mean_elevation
    ucrb_selected_gdf_32613.loc[idx, 'max_elevation'] = max_elevation
    ucrb_selected_gdf_32613.loc[idx, 'min_elevation'] = min_elevation

# %%
# separate mean elevation into 3 categories
categories = pd.qcut(ucrb_selected_gdf_32613['mean_elevation'],3, labels=['low', 'medium', 'high'])
ucrb_selected_gdf_32613['elevation_category'] = categories.astype(str)
# save the gdf
ucrb_selected_gdf_32613.to_file('../data/geodata/ucrb_selected_basins.geojson', driver='GeoJSON')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ucrb_selected_gdf_32613
#
# NameError: name 'ucrb_selected_gdf_32613' is not defined
