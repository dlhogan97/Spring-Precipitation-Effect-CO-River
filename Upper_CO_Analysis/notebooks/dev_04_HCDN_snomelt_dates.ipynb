# %%
import rioxarray as rxr
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr
import numpy as np
# Out:
# /home/dlhogan/.conda/envs/soil_moisture_env/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.11.1-CAPI-1.17.1). Conversions between both will be slow.
#   warnings.warn(

# %%
# import basin boundaries
hcdn_basins = gpd.read_file('../data/geodata/basin_station_sntl.json')
# create a filter to select only the basin of interest
basin_filter = hcdn_basins['gage'].isin(['09124500','09112500','09035900'])
# apply the filter
example_basins = hcdn_basins[basin_filter]
# check the crs 
print(example_basins.crs)
# write the crs to 32613
example_basins = example_basins.set_crs(32613, allow_override=True)
# check the crs again
print(example_basins.crs)
# Out:
# epsg:4326
# EPSG:32613

# %%
# Now lets open the mean imagery for snowmelt 

# open the mean snowmelt image
mean_snowmelt = rxr.open_rasterio('../data/snowdata/Snowmelt_Timing_North_America_Mean_2001_2018_V2.tif', masked=True).squeeze()
# reproject the image to the basin crs
mean_snowmelt = mean_snowmelt.rio.reproject(example_basins.crs)

# %%
# create and empty dataframe with mean, median, and std columns 
basin_stats = pd.DataFrame(columns=['mean','median','std'], index=example_basins['gage'])
# clip the image to the first basin in example_basins
for site in example_basins['gage']:
    mean_snowmelt_clip = mean_snowmelt.rio.clip(example_basins[example_basins['gage']==site].geometry, example_basins.crs, drop=True)
    # filter values below 100
    # mean_snowmelt_clip = mean_snowmelt_clip.where(mean_snowmelt_clip>90)
    # add values to basin_stats
    basin_stats.loc[site] = [mean_snowmelt_clip.mean().values, mean_snowmelt_clip.median().values, mean_snowmelt_clip.std().values]
    fig, ax = plt.subplots()
    mean_snowmelt_clip.plot(ax=ax,vmin=100, vmax=170)
    ax.grid()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/dlhogan/GitHub/Spring-Precipitation-Effect-CO-River/Upper_CO_Analysis/notebooks/dev_04_HCDN_snomelt_dates.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell://ssh-remote%2Bj-lundquist-3.ce.washington.edu/home/dlhogan/GitHub/Spring-Precipitation-Effect-CO-River/Upper_CO_Analysis/notebooks/dev_04_HCDN_snomelt_dates.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # clip the image to the first basin in example_basins
#       <a href='vscode-notebook-cell://ssh-remote%2Bj-lundquist-3.ce.washington.edu/home/dlhogan/GitHub/Spring-Precipitation-Effect-CO-River/Upper_CO_Analysis/notebooks/dev_04_HCDN_snomelt_dates.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> for site in example_basins['gage']:
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bj-lundquist-3.ce.washington.edu/home/dlhogan/GitHub/Spring-Precipitation-Effect-CO-River/Upper_CO_Analysis/notebooks/dev_04_HCDN_snomelt_dates.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     mean_snowmelt_clip = mean_snowmelt.rio.clip(example_basins[example_basins['gage']==site].geometry, example_basins.crs, drop=True)
#       <a href='vscode-notebook-cell://ssh-remote%2Bj-lundquist-3.ce.washington.edu/home/dlhogan/GitHub/Spring-Precipitation-Effect-CO-River/Upper_CO_Analysis/notebooks/dev_04_HCDN_snomelt_dates.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     # filter values below 100
#       <a href='vscode-notebook-cell://ssh-remote%2Bj-lundquist-3.ce.washington.edu/home/dlhogan/GitHub/Spring-Precipitation-Effect-CO-River/Upper_CO_Analysis/notebooks/dev_04_HCDN_snomelt_dates.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     # mean_snowmelt_clip = mean_snowmelt_clip.where(mean_snowmelt_clip>90)
#       <a href='vscode-notebook-cell://ssh-remote%2Bj-lundquist-3.ce.washington.edu/home/dlhogan/GitHub/Spring-Precipitation-Effect-CO-River/Upper_CO_Analysis/notebooks/dev_04_HCDN_snomelt_dates.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     # add values to basin_stats
#       <a href='vscode-notebook-cell://ssh-remote%2Bj-lundquist-3.ce.washington.edu/home/dlhogan/GitHub/Spring-Precipitation-Effect-CO-River/Upper_CO_Analysis/notebooks/dev_04_HCDN_snomelt_dates.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     basin_stats.loc[site] = [mean_snowmelt_clip.mean().values, mean_snowmelt_clip.median().values, mean_snowmelt_clip.std().values]
#
# File ~/.conda/envs/soil_moisture_env/lib/python3.9/site-packages/rioxarray/raster_array.py:933, in RasterArray.clip(self, geometries, crs, all_touched, drop, invert, from_disk)
#     925     cropped_ds = _clip_from_disk(
#     926         self._obj,
#     927         geometries=geometries,
#    (...)
#     930         invert=invert,
#     931     )
#     932 if cropped_ds is None:
# --> 933     cropped_ds = _clip_xarray(
#     934         self._obj,
#     935         geometries=geometries,
#     936         all_touched=all_touched,
#     937         drop=drop,
#     938         invert=invert,
#     939     )
#     941 if (
#     942     cropped_ds.coords[self.x_dim].size < 1
#     943     or cropped_ds.coords[self.y_dim].size < 1
#     944 ):
#     945     raise NoDataInBounds(
#     946         f"No data found in bounds.{_get_data_var_message(self._obj)}"
#     947     )
#
# File ~/.conda/envs/soil_moisture_env/lib/python3.9/site-packages/rioxarray/raster_array.py:221, in _clip_xarray(xds, geometries, all_touched, drop, invert)
#     211 def _clip_xarray(
#     212     xds: xarray.DataArray,
#     213     geometries: Iterable,
#    (...)
#     216     invert: bool,
#     217 ) -> xarray.DataArray:
#     218     """
#     219     clip the xarray DataArray
#     220     """
# --> 221     clip_mask_arr = geometry_mask(
#     222         geometries=geometries,
#     223         out_shape=(int(xds.rio.height), int(xds.rio.width)),
#     224         transform=xds.rio.transform(recalc=True),
#     225         invert=not invert,
#     226         all_touched=all_touched,
#     227     )
#     228     clip_mask_xray = xarray.DataArray(
#     229         clip_mask_arr,
#     230         dims=(xds.rio.y_dim, xds.rio.x_dim),
#     231     )
#     232     cropped_ds = xds.where(clip_mask_xray)
#
# File ~/.conda/envs/soil_moisture_env/lib/python3.9/site-packages/rasterio/env.py:394, in ensure_env.<locals>.wrapper(*args, **kwds)
#     392 else:
#     393     with Env.from_defaults():
# --> 394         return f(*args, **kwds)
#
# File ~/.conda/envs/soil_moisture_env/lib/python3.9/site-packages/rasterio/features.py:71, in geometry_mask(geometries, out_shape, transform, all_touched, invert)
#      37 """Create a mask from shapes.
#      38
#      39 By default, mask is intended for use as a
#    (...)
#      67
#      68 """
#      69 fill, mask_value = (0, 1) if invert else (1, 0)
# ---> 71 return rasterize(
#      72     geometries,
#      73     out_shape=out_shape,
#      74     transform=transform,
#      75     all_touched=all_touched,
#      76     fill=fill,
#      77     default_value=mask_value).astype('bool')
#
# File ~/.conda/envs/soil_moisture_env/lib/python3.9/site-packages/rasterio/env.py:391, in ensure_env.<locals>.wrapper(*args, **kwds)
#     388 @wraps(f)
#     389 def wrapper(*args, **kwds):
#     390     if local._env:
# --> 391         return f(*args, **kwds)
#     392     else:
#     393         with Env.from_defaults():
#
# File ~/.conda/envs/soil_moisture_env/lib/python3.9/site-packages/rasterio/features.py:353, in rasterize(shapes, out_shape, fill, out, transform, all_touched, merge_alg, default_value, dtype)
#     350         raise ValueError('Invalid out_shape, must be 2D')
#     352     out = np.empty(out_shape, dtype=dtype)
# --> 353     out.fill(fill)
#     355 else:
#     356     raise ValueError('Either an out_shape or image must be provided')
#
# KeyboardInterrupt:

# %%
# save basin_stats
basin_stats.to_csv('../data/snowdata/example_basin_snow_stats.csv')

# %%
basin_stats
# Out:
#                mean              median                 std
# gage
# 09035900  160.90076               165.0  13.863846778869629
# 09112500  139.77406  140.11111450195312  25.298030853271484
# 09124500  133.84749  136.55555725097656   26.73946189880371

# %% [markdown]
# ### Comparing to SNTL site values

# %%
# open ucrb_hcdn_sntl_all_20220930.nc
ds = xr.open_dataset('../data/snowdata/ucrb_hcdn_sntl_all_20220930.nc')
example_sntl = ds.sel(Location=' 380:CO:SNTL')['WTEQ']
melt_timing = np.zeros(len(example_sntl.Date.dt.year.to_pandas().unique()))
for i,year in enumerate(example_sntl.Date.dt.year.to_pandas().unique()):
    tmp = example_sntl.where(example_sntl.Date.dt.year==year, drop=True)
    # calculate the 7 day rolling mean of wteq
    tmp_7day = tmp.rolling(Date=7, center=True).mean()
    # make values less than 0 equal to 0 but keep nans
    tmp_7day = tmp_7day.where((tmp_7day>0) | (tmp_7day.isnull()), 0)
    # drop values greater than 220
    # tmp_7day = tmp_7day.where(tmp_7day<220, 0)

    # print the day of year of the first zero value
    if tmp_7day.idxmin(dim='Date').dt.dayofyear.values > 210:
        melt_timing[i] = np.nan
    else:
        melt_timing[i] = (tmp_7day.idxmin(dim='Date').dt.dayofyear.values)
