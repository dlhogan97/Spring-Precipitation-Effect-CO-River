# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
stossel_day_1 = [-48,
                 -35,
                 -26,
                 -41,
                 -40]

stossel_day_2 = [-49,
                 -54,
                 -12,
                 -33,
                 -38]
                 
stossel_night_1 = [	21,
				    13,
				    12,
				    27,
				    0,
			        9]
stossel_night_2 = [21,
                   14,
                   19,
                   30,
                   -3,
                   	8]

plt.scatter(stossel_day_1,stossel_day_2, color='r', label='Day')
plt.scatter(stossel_night_1,stossel_night_2, color='blue', label='Night')
plt.xlabel('Box 1 Mass Change (g)')
plt.ylabel('Box 2 Mass Change (g)')  
plt.axvline(0, color='k')
plt.axhline(0, color='k')
plt.legend()             
plt.ylim(-60,60)
plt.xlim(-60,60)
# Out:
# (-60.0, 60.0)
